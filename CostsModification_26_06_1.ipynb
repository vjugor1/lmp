# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils
# %matplotlib inline

# %%
from case1 import case1

# %%
# %%HTML
# <style type="text/css">
# table, td{
#     border-style: solid;
# }
# th {
#   background-color: #4CAF50;
#   color: white;
# }
# tr:nth-child(even) {background-color: #f0f0f0;}
# tr:hover {background-color: #4CAF50;}
# Out:
# <style type="text/css">
# table, td{
#     border-style: solid;
# }
# th {
#   background-color: #4CAF50;
#   color: white;
# }
# tr:nth-child(even) {background-color: #f0f0f0;}
# tr:hover {background-color: #4CAF50;}

# %%
cl = case1()
# 0 1 ... 2 3 1

# %%
cl.draw_ppn_net()

# %%
cl.prepare_case()

# %%
cl.runopf_case()
# Out:
# PYPOWER Version 5.1.4, 27-June-2018 -- AC Optimal Power Flow
# Python Interior Point Solver - PIPS, Version 1.0, 07-Feb-2011
# Converged!
#
# Converged in 1.77 seconds
# Objective Function Value = 216519.75 $/hr
# ...
# |     System Summary                                                           |
# ...
#
# How many?                How much?              P (MW)            Q (MVAr)
# ---------------------    -------------------  -------------  -----------------
# Buses             30     Total Gen Capacity     335.0        -140.0 to 405.9
# Generators         9     On-line Capacity       335.0        -140.0 to 405.9
# Committed Gens     9     Generation (actual)    151.2              93.3
# Loads             17     Load                   147.6              91.9
#   Fixed           17       Fixed                147.6              91.9
#   Dispatchable     0       Dispatchable           0.0 of 0.0        0.0
# Shunts             2     Shunt (inj)             -0.0               0.2
# ...

# %%
cl.get_price_formings()
# Out:
# Price forming bus #22	 C_g=1100.000000
# Price forming bus #27	 C_g=1200.000000
# Price forming bus #23	 C_g=10000.000000
# [21, 26, 22]

# %%
cl.solve(threshold=2000)
# Out:
# #Var = 200
# #Eq = 60
# Underdetermined:  True
# x:
# lam_p, |lam_p| = 28
# lam_q, |lam_q| = 30
# sigma, |sigma| = 82
# mu, |mu| = 60
# f(x^*) = 6.198561503748977e-09

# %%
cl.plot(0., 10000)

# %% [markdown]
# ##
